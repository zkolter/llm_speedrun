# %% [markdown]
# ### Mugrade boilerplate

# %%
### Run this cell to install and import the homework tests
# !pip install --upgrade git+https://github.com/locuslab/mugrade.git
# !wget -nc https://raw.githubusercontent.com/zkolter/llm_speedrun/refs/heads/main/part2_llm_arch_tests.py

import mugrade
import os
from part2_llm_arch_tests import *
os.environ["MUGRADE_HW"] = "Part 2 - LLM Architecture"
os.environ["MUGRADE_KEY"] = "" ### Your key here

# %% [markdown]
# ### LLM Transformer Architecture
#
# Implement the LLM architecture presented in class.  This will _only_ be the architecture portion in this part of the assignment, and the training will be done in the next portion (released after the next lecture).
#
# Note that there was error with the version typed live in class, and `self.params` was replaced by `llm.params` within the class in several instaces.  Internal reference to parameters (or the `buffer`) within the class should also be done via `self.params`.

# %%
import torch
import math

# @mugrade.local_tests
def embedding(x, weights, dtype):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

# @mugrade.local_tests
def linear(x, weights):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

                   
# @mugrade.local_tests
def silu(x):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

# @mugrade.local_tests
def rms_norm(x):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

# @mugrade.local_tests
def softmax(x):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

# @mugrade.local_tests
def self_attn(q,k,v,mask):
    ### BEGIN YOUR CODE
    pass
    ### END YOUR CODE

class LLM:
    # @mugrade.local_tests
    def rope(self, x):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE

    # @mugrade.local_tests
    def multihead_attn(self, x, layer, mask):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE

    # @mugrade.local_tests
    def mlp(self, x, layer):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE

    # @mugrade.local_tests
    def transformer_block(self, x, layer, mask):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE
    
    # @mugrade.local_tests
    def __init__(self, config):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE
            
    # @mugrade.local_tests
    def __call__(self, tokens):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE
        
    # @mugrade.local_tests
    def save(self, filename):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE

    # @mugrade.local_tests
    def load(self, filename):
        ### BEGIN YOUR CODE
        pass
        ### END YOUR CODE

# %% [markdown]
# The tests for the code above will all pass based upon specific instances from the test cases, but if you want to try out the construction on a realistic (but still very small) model class, you can try out the following model, using the code to load the configuration from class.

# %%
# %%writefile config.d12.json
# {
#     "depth": 12,
#     "aspect_ratio": 64,
#     "head_dim": 128,
#     "mlp_multiple": 4,
#     "vocab_size": 32768,
#     "seq_len": 2048,
#     "num_gpus": 1,
#     "batch_size": 32,
#     "token_multiple": 20,
#     "rope_theta": 10000,
#     "dtype": "bfloat16",
#     "lr": 1e-3,
#     "data_mix": {
#         "fineweb-edu-10BT.shuffle.bin": 0.875,
#         "smoltalk.shuffle.bin": 0.125
#     },
#     "tokenizer": "tokenizer_50M.bpe"
# }
# Out:
# Overwriting config.d12.json
